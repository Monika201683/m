# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Monik\\Downloads\\newplacementdata.csv")
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (15,5))
plt.subplot(121)
sns.distplot(df["cgpa"])
plt.subplot(122)
sns.distplot(df["placement_exam_marks"])
plt.show()
# Out:
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\106607889.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["cgpa"])
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\106607889.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["placement_exam_marks"])

# %%
df["placement_exam_marks"].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.distplot(x=df["placement_exam_marks"])
# Out:
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\3390081902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["placement_exam_marks"])
# <Axes: ylabel='Density'>

# %%
percentile25 = df["placement_exam_marks"].quantile(0.25)
percentile75 = df["placement_exam_marks"].quantile(0.75)

# %%
percentile25
# Out:
# 17.0

# %%
percentile75
# Out:
# 44.0

# %%
IQR = percentile75-percentile25

# %%
IQR
# Out:
# 27.0

# %%
upper_limit = percentile75+1.5*IQR

# %%
upper_limit
# Out:
# 84.5

# %%
lower_limit  = percentile25-1.5*IQR

# %%
lower_limit
# Out:
# -23.5

# %%
df[df["placement_exam_marks"]>upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                    94       1
# 40   6.60                    86       1
# 61   7.51                    86       0
# 134  6.33                    93       0
# 162  7.80                    90       0
# 283  7.09                    87       0
# 290  8.38                    87       0
# 311  6.97                    87       1
# 324  6.64                    90       0
# 630  6.56                    96       1
# 685  6.05                    87       1
# 730  6.14                    90       1
# 771  7.31                    86       1
# 846  6.99                    97       0
# 917  5.95                   100       0

# %%
df[df["placement_exam_marks"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %%
newdf = df[df["placement_exam_marks"]>upper_limit]
newdf
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                    94       1
# 40   6.60                    86       1
# 61   7.51                    86       0
# 134  6.33                    93       0
# 162  7.80                    90       0
# 283  7.09                    87       0
# 290  8.38                    87       0
# 311  6.97                    87       1
# 324  6.64                    90       0
# 630  6.56                    96       1
# 685  6.05                    87       1
# 730  6.14                    90       1
# 771  7.31                    86       1
# 846  6.99                    97       0
# 917  5.95                   100       0

# %%
plt.figure(figsize = (15,5))
plt.subplot(221)
sns.distplot(df["placement_exam_marks"])
plt.subplot(222)
sns.boxplot(df["placement_exam_marks"])

plt.subplot(223)
sns.distplot(newdf["placement_exam_marks"])
plt.subplot(224)
sns.boxplot(newdf["placement_exam_marks"])
plt.show()
# Out:
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\3738993077.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["placement_exam_marks"])
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\3738993077.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(newdf["placement_exam_marks"])

# %%
new_df_cap= df.copy()

new_df_cap["placement_exam_marks"] = np.where(
    new_df_cap["placement_exam_marks"]> upper_limit,
    upper_limit,

    np.where(
        new_df_cap["placement_exam_marks"]<lower_limit,
        lower_limit,
        new_df_cap["placement_exam_marks"]))

# %%
new_df_cap
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize = (15,8))
plt.subplot(221)
sns.distplot(df["placement_exam_marks"])
plt.subplot(222)
sns.boxplot(df["placement_exam_marks"])

plt.subplot(223)
sns.distplot(new_df_cap["placement_exam_marks"])
plt.subplot(224)
sns.boxplot(new_df_cap["placement_exam_marks"])
plt.show()
# Out:
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\4289847028.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["placement_exam_marks"])
# C:\Users\Monik\AppData\Local\Temp\ipykernel_20764\4289847028.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_cap["placement_exam_marks"])

# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:\\Users\\Monik\\Downloads\\newplacementdata.csv")
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
x=df.drop(columns=["placed"],axis=1)
y=df["placed"]

# %%
X,y= load_diabetes(return_X_y = True)
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train ,X_test, y_train, y_test=train_test_split(X, y, random_state=42, test_size=0.2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.4526027629719195

# %%
class SGDRegressor :
    def __init__(self , learning_rate =0.01, epochs =100):
        self.coef_ =None
        self.lr = learning_rate
        self.intercept_ = None
        self.epochs = epochs

    def fit(self, X_train, y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                idx = np.random.randint(0, X_train.shape[0])
                y_hat=np.dot(X_train[idx] , self.coef_) + self.intercept_

                intercept_der = -2*(y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr*intercept_der)
                coef_der = -2*np.dot((y_train[idx] - y_hat) , X_train[idx])
                self.coef_= self.coef_-(self.lr*coef_der)

        print(self.intercept_ , self.coef_)

    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(learning_rate=0.01, epochs=50)

# %%
sgd.fit(X_train, y_train)
# Out:
# 148.90696076349556 [  60.23831114  -86.44340794  366.22815941  248.92714645   -1.53163277
#   -39.11637148 -182.03994015  151.96761246  289.90800943  160.64625706]

# %%
y_pred = sgd.predict(X_test)

# %%
y_pred
# Out:
# array([154.43793171, 161.82110176, 152.74739788, 269.63524855,
#        138.60824432, 115.62161588, 232.80110995, 197.96235635,
#        101.11356251, 126.77912513, 103.07059488, 137.42242374,
#         65.48167989, 207.64302029, 116.66269922, 132.84347305,
#        218.02630394, 237.11877801, 171.03121793, 205.46007926,
#        177.52595206, 100.34013687,  84.27770185, 185.09276784,
#        141.36899586, 163.30733758, 177.66261984, 171.04861795,
#         57.82063152, 133.05641597, 171.30155786,  98.94492551,
#        139.04380382, 180.57710825, 173.38275369, 183.9105179 ,
#        135.89585239, 139.00642627, 167.29099297,  69.54030883,
#         93.68686667, 121.30420998, 150.73496122, 166.30443104,
#        166.12041957,  74.16241317,  85.74845226, 101.23971346,
#         68.56852768, 140.94237982, 132.43584723,  69.78060129,
#        127.81658978, 111.83204753, 177.68711295, 137.0053241 ,
#        109.67274695, 186.73224481, 110.71042391,  70.83071223,
#        181.45356581, 173.95561262, 134.13868659, 124.11531454,
#        128.71121329, 183.47284706, 174.2539846 , 158.00490458,
#         99.31180392, 141.5572966 , 170.25485871, 196.34185561,
#        233.11375777, 138.97682245,  87.47929989, 161.49604558,
#        198.38877336, 182.01181082, 163.4628696 , 185.51305533,
#        113.49909968, 115.51927749,  64.24276201,  76.18161291,
#        114.93488225,  91.06690303,  71.36039304,  68.36959069,
#        141.59871097])

# %%
r2_score(y_test , y_pred)
# Out:
# 0.4434241322344772

# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y= load_diabetes(return_X_y = True)
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train ,X_test, y_train, y_test=train_test_split(X, y, random_state=42, test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [  37.90402135 -241.96436231  542.42875852  347.70384391 -931.48884588
#   518.06227698  163.41998299  275.31790158  736.1988589    48.67065743]
# 151.34560453985995

# %%
y_pred = lr.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.4526027629719195

# %%
import random
class MGBRegressor :
    def __init__(self ,batch_size, learning_rate =0.01, epochs =100):
        self.coef_ =None
        self.lr = learning_rate
        self.intercept_ = None
        self.epochs = epochs
        self.batch_size = batch_size

    def fit(self, X_train, y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):
            for j in range(int(X_train.shape[0]/self.batch_size)):
                idx = random.sample(range(X_train.shape[0]),self.batch_size)
                y_hat=np.dot(X_train[idx] , self.coef_) + self.intercept_

                intercept_der = -2*np.mean(y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr*intercept_der)
                coef_der = -2*np.dot((y_train[idx] - y_hat) , X_train[idx])
                self.coef_= self.coef_-(self.lr*coef_der)

        print(self.intercept_ , self.coef_)

    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
mbr = MGBRegressor(batch_size = int(X_train.shape[0]/10) , learning_rate=0.01, epochs=50)

# %%
mbr

# %%
mbr.fit(X_train, y_train)
# Out:
# 151.16836648125943 [  58.77736452  -90.45346343  357.66333306  259.63673331    1.36438678
#   -40.61301779 -172.98634149  145.47078569  286.2156065   153.4953469 ]

# %%
y_pred = mbr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# -4.008638023445834
